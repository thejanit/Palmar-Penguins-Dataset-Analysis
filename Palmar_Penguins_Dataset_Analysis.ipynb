# %%
# Importing Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading csv file

df = pd.read_csv("penguins_size.csv")
df.head()
# Out:
#   species     island  culmen_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen              39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen              39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen              40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen               NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen              36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.columns
# Out:
# Index(['species', 'island', 'culmen_length_mm', 'culmen_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
df['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df.shape
# Out:
# (344, 7)

# %%
df2 = df.dropna()
df2.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %%
df2.shape
# Out:
# (334, 7)

# %%
df2.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        334.000000       334.000000         334.000000   334.000000
# mean          43.994311        17.160479         201.014970  4209.056886
# std            5.460521         1.967909          14.022175   804.836129
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.575000        18.700000         213.000000  4793.750000
# max           59.600000        21.500000         231.000000  6300.000000

# %%
sns.barplot(data=df2, x='species', y='culmen_length_mm')

# %%
sns.kdeplot(data=df2, hue='species', x='flipper_length_mm', multiple='stack')

# %%
sns.histplot(data=df2, hue='species', x='island')

# %%
sns.pairplot(data=df2, hue='species', kind='scatter', height=2.7)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.scatterplot(data=df2, hue='species', x='body_mass_g', y='flipper_length_mm')
plt.show()
